# %%
#importing important libraries:

import requests
from bs4 import BeautifulSoup

# %%
# request is used to pull the URL of the website:
url = 'https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops'
req = requests.get(url)

# %%
#start scraping:
soup = BeautifulSoup(req.content, 'lxml')
Product_title = soup.find('a', class_ = 'title').text
price = soup.find('h4', class_ = 'price float-end card-title pull-right').text
des = soup.find('p', class_ = 'description card-text').text
print(Product_title)
print(price)
print(des)
# Out:
# Asus VivoBook...
# $295.99
# Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd

# %%
#This block scaping all the information from the test website:
information = soup.find_all('div', class_ = 'col-md-4 col-xl-4 col-lg-4')
for products in information:
    titles = products.a.text
    prices = products.h4.text
    descs = products.p.text
    print(titles)
    print(prices)
    print(descs)
    print()
# Out:
# Asus VivoBook...
# $295.99
# Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd
#
# Prestigio Smar...
# $299
# Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam
#
# Prestigio Smar...
# $299
# Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam
#
# Aspire E1-510
# $306.99
# 15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux
#
# Lenovo V110-15...
# $321.94
# Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home
#
# Lenovo V110-15...
# $356.49
# Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd
#
# Hewlett Packar...
# $364.46
# Hewlett Packard 250 G6 Dark Ash Silver, 15.6" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS
#
# Acer Aspire 3...
# $372.7
# ...
